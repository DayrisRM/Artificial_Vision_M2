# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a40c28f-79ea-4c78-bc08-2b430f6c706d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a40c28f-79ea-4c78-bc08-2b430f6c706d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving US_Original_dataset_final.zip to US_Original_dataset_final.zip

# %%
import zipfile
import io
data = zipfile.ZipFile(io.BytesIO(uploaded['US_Original_dataset_final.zip']), 'r')
data.extractall()

# %%
import os

# %%
train_path = '/content/US_Original_dataset_final/train'
test_path = '/content/US_Original_dataset_final/test'
val_path = '/content/US_Original_dataset_final/validation'

# %% [markdown]
# ---
# Common functions

# %%
classes = ['Benign', 'Malignant']

# %%
from matplotlib import pyplot
def summarize_diagnostics(history):
  # plot loss
  pyplot.figure(0)
  pyplot.title('Loss')
  pyplot.plot(history.history['loss'], color='blue', label='train')
  pyplot.plot(history.history['val_loss'], color='orange', label='test')
  pyplot.legend(['loss','val_loss']) 

  # plot accuracy
  pyplot.figure(1)
  pyplot.title('Classification Accuracy')
  pyplot.plot(history.history['accuracy'], color='blue', label='train')
  pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
  pyplot.legend(['accuracy','val_accuracy'])

# %%
#functions to build confusion matrix
from tqdm import tqdm
import os
import cv2
import numpy as np
import itertools
from sklearn.metrics import accuracy_score, confusion_matrix

def load_data(dir_path):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels



def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=pyplot.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    pyplot.figure(figsize = (6,6))
    pyplot.imshow(cm, interpolation='nearest', cmap=cmap)
    pyplot.title(title)
    pyplot.colorbar()
    tick_marks = np.arange(len(classes))
    pyplot.xticks(tick_marks, classes, rotation=90)
    pyplot.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        pyplot.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    pyplot.tight_layout()
    pyplot.ylabel('True label')
    pyplot.xlabel('Predicted label')
    pyplot.show()

x_test, y_test, labels = load_data('/content/US_Original_dataset_final/test/')
print(labels)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 27.96it/s]
# 40 images loaded from /content/US_Original_dataset_final/test/ directory.
# {0: 'Benign', 1: 'Malignant'}

# %%
from sklearn.metrics import classification_report
def validateResults(model):   
  predictions = model.predict(x_test, batch_size=32)
  y_pred = np.argmax(predictions, axis=1) 
  y_true = np.argmax(y_test, axis=0)

  print("\n"+ classification_report(y_test, y_pred, target_names=classes))
  print(confusion_matrix(y_test, y_pred))
  confusion_mtx = confusion_matrix(y_test, y_pred)
  cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)

# %% [markdown]
# ---
#
# VGG models

# %%
from tensorflow.keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.applications.vgg16 import VGG16
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
# define cnn model
def BuildVGG16():
  # load model
  model = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
  # mark loaded layers as not trainable
  for layer in model.layers:
    layer.trainable = False
  
  last_layer = model.get_layer('block5_pool')
  last_output = last_layer.output
  x = tf.keras.layers.GlobalMaxPooling2D()(last_output)
  x = tf.keras.layers.Dense(512, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(2, activation='sigmoid')(x) #2 clases de salida  
  model = tf.keras.Model(model.input, x)    

  return model

# %%
modelVGG16 = BuildVGG16()
modelVGG16.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 14,978,370
# Trainable params: 263,682
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
EPOCHS = 100
batch_size=32
es = EarlyStopping(monitor='val_loss', patience=20, verbose=1, min_delta=1e-4)
rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, verbose=1, min_delta=1e-4)

# %%
datagen = ImageDataGenerator(rescale=1./255, rotation_range = 5, width_shift_range = 0.1, 
                               height_shift_range = 0.1, horizontal_flip = True)

train_it = datagen.flow_from_directory(train_path, batch_size=batch_size, target_size=(224, 224))
validation_it = datagen.flow_from_directory(val_path, batch_size=batch_size, target_size=(224, 224))
test_it = datagen.flow_from_directory(test_path, batch_size=batch_size, target_size=(224, 224))
# Out:
# Found 98 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
def fitVGG16v1():
  modelv1 = BuildVGG16()
  modelv1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  # fit model
  historyVGG16_v1 = modelv1.fit(
      train_it, 
      steps_per_epoch=len(train_it),
      validation_data=validation_it, 
      validation_steps=len(validation_it), 
      epochs=EPOCHS, 
      verbose=1,
      callbacks=[rlrop, es])
  
  return historyVGG16_v1, modelv1

# %%
historyVGG16_v1, modelv1 = fitVGG16v1()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 558ms/step - loss: 1.0801 - accuracy: 0.5714 - val_loss: 0.8060 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 2/100
# 4/4 [==============================] - 2s 444ms/step - loss: 0.6357 - accuracy: 0.6531 - val_loss: 0.7994 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/100
# 4/4 [==============================] - 2s 436ms/step - loss: 0.6839 - accuracy: 0.7143 - val_loss: 0.9151 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 4/100
# 4/4 [==============================] - 2s 409ms/step - loss: 0.6846 - accuracy: 0.6735 - val_loss: 0.7230 - val_accuracy: 0.4400 - lr: 0.0010
# Epoch 5/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.6899 - accuracy: 0.5816 - val_loss: 0.7884 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.8840 - accuracy: 0.6939 - val_loss: 1.3125 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 7/100
# 4/4 [==============================] - 2s 408ms/step - loss: 0.9404 - accuracy: 0.6939 - val_loss: 0.6525 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 8/100
# 4/4 [==============================] - 2s 529ms/step - loss: 1.0620 - accuracy: 0.4388 - val_loss: 0.9078 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 9/100
# 4/4 [==============================] - 2s 432ms/step - loss: 0.7266 - accuracy: 0.5918 - val_loss: 0.7287 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 10/100
# 4/4 [==============================] - 2s 442ms/step - loss: 0.7539 - accuracy: 0.7347 - val_loss: 1.2753 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 11/100
# 4/4 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.6939
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 [==============================] - 2s 568ms/step - loss: 0.8925 - accuracy: 0.6939 - val_loss: 1.0436 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 12/100
# 4/4 [==============================] - 2s 434ms/step - loss: 0.7096 - accuracy: 0.7041 - val_loss: 0.9536 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 13/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.6907 - accuracy: 0.7041 - val_loss: 0.8368 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 14/100
# 4/4 [==============================] - 2s 691ms/step - loss: 0.5780 - accuracy: 0.7449 - val_loss: 0.7416 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 15/100
# 4/4 [==============================] - 2s 455ms/step - loss: 0.6225 - accuracy: 0.7041 - val_loss: 0.6468 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 4/4 [==============================] - 2s 437ms/step - loss: 0.5975 - accuracy: 0.7653 - val_loss: 0.6778 - val_accuracy: 0.6000 - lr: 1.0000e-07
# Epoch 38/100
# 4/4 [==============================] - 2s 441ms/step - loss: 0.5347 - accuracy: 0.7653 - val_loss: 0.6571 - val_accuracy: 0.6000 - lr: 1.0000e-08
# Epoch 39/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.5474 - accuracy: 0.7245 - val_loss: 0.6767 - val_accuracy: 0.6000 - lr: 1.0000e-08
# Epoch 40/100
# 4/4 [==============================] - 2s 414ms/step - loss: 0.6122 - accuracy: 0.7449 - val_loss: 0.7358 - val_accuracy: 0.6000 - lr: 1.0000e-08
# Epoch 41/100
# 4/4 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.7551
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 4/4 [==============================] - 2s 564ms/step - loss: 0.5496 - accuracy: 0.7551 - val_loss: 0.6970 - val_accuracy: 0.6000 - lr: 1.0000e-08
# Epoch 41: early stopping

# %%
summarize_diagnostics(historyVGG16_v1)

# %%
validateResults(modelv1)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.73      0.85      0.79        26
#    Malignant       0.60      0.43      0.50        14
#
#     accuracy                           0.70        40
#    macro avg       0.67      0.64      0.64        40
# weighted avg       0.69      0.70      0.69        40
#
# [[22  4]
#  [ 8  6]]

# %% [markdown]
# VGG16 v2

# %%
def fitVGG16v2():
  datagen2 = ImageDataGenerator(rescale=1./255)
  
  train_it_v2 = datagen2.flow_from_directory(train_path, batch_size=batch_size, target_size=(224, 224))
  validation_it_v2 = datagen2.flow_from_directory(val_path, batch_size=batch_size, target_size=(224, 224))
  test_it_v2 = datagen2.flow_from_directory(test_path, batch_size=batch_size, target_size=(224, 224))

  modelv2 = BuildVGG16()
  modelv2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  # fit model
  historyVGG16_v2 = modelv2.fit(
      train_it_v2, 
      steps_per_epoch=len(train_it_v2),
      validation_data=validation_it_v2, 
      validation_steps=len(validation_it_v2), 
      epochs=EPOCHS, 
      verbose=1)
  
  return historyVGG16_v2, modelv2

# %%
historyVGG16_v2, modelv2 = fitVGG16v2()
# Out:
# Found 98 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# Epoch 1/100
# 4/4 [==============================] - 2s 278ms/step - loss: 0.9271 - accuracy: 0.5918 - val_loss: 0.7289 - val_accuracy: 0.6000
# Epoch 2/100
# 4/4 [==============================] - 1s 189ms/step - loss: 0.7600 - accuracy: 0.5612 - val_loss: 0.6731 - val_accuracy: 0.6400
# Epoch 3/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.7209 - accuracy: 0.6837 - val_loss: 0.8710 - val_accuracy: 0.6000
# Epoch 4/100
# 4/4 [==============================] - 1s 185ms/step - loss: 0.6536 - accuracy: 0.7143 - val_loss: 0.7021 - val_accuracy: 0.6000
# Epoch 5/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.6034 - accuracy: 0.7143 - val_loss: 0.6426 - val_accuracy: 0.6000
# Epoch 6/100
# 4/4 [==============================] - 1s 234ms/step - loss: 0.7206 - accuracy: 0.5510 - val_loss: 0.6445 - val_accuracy: 0.7600
# Epoch 7/100
# 4/4 [==============================] - 1s 189ms/step - loss: 0.6009 - accuracy: 0.6735 - val_loss: 0.6571 - val_accuracy: 0.6000
# Epoch 8/100
# 4/4 [==============================] - 1s 191ms/step - loss: 0.7119 - accuracy: 0.7041 - val_loss: 0.8417 - val_accuracy: 0.6000
# Epoch 9/100
# 4/4 [==============================] - 1s 189ms/step - loss: 0
# 4/4 [==============================] - 1s 232ms/step - loss: 0.2678 - accuracy: 0.8776 - val_loss: 0.7385 - val_accuracy: 0.6400
# Epoch 86/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.2754 - accuracy: 0.8878 - val_loss: 0.6233 - val_accuracy: 0.7200
# Epoch 87/100
# 4/4 [==============================] - 1s 233ms/step - loss: 0.2384 - accuracy: 0.9082 - val_loss: 0.5884 - val_accuracy: 0.7600
# Epoch 88/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.3147 - accuracy: 0.8776 - val_loss: 0.6039 - val_accuracy: 0.7200
# Epoch 89/100
# 4/4 [==============================] - 1s 186ms/step - loss: 0.2619 - accuracy: 0.8878 - val_loss: 0.5827 - val_accuracy: 0.8000
# Epoch 90/100
# 4/4 [==============================] - 1s 232ms/step - loss: 0.2727 - accuracy: 0.8878 - val_loss: 0.6457 - val_accuracy: 0.6000
# Epoch 91/100
# 4/4 [==============================] - 1s 192ms/step - loss: 0.2217 - accuracy: 0.8980 - val_loss: 0.6038 - val_accuracy: 0.7200
# Epoch 92/100
# 4/4 [==============================] - 1s 194ms/step - loss: 0.2987 - accuracy: 0.8776 - val_loss: 0.6825 - val_accuracy: 0.6400
# Epoch 93/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.3494 - accuracy: 0.8469 - val_loss: 0.5834 - val_accuracy: 0.7600
# Epoch 94/100
# 4/4 [==============================] - 1s 175ms/step - loss: 0.1898 - accuracy: 0.9490 - val_loss: 0.7724 - val_accuracy: 0.6400
# Epoch 95/100
# 4/4 [==============================] - 1s 237ms/step - loss: 0.3399 - accuracy: 0.8469 - val_loss: 0.8947 - val_accuracy: 0.6000
# Epoch 96/100
# 4/4 [==============================] - 1s 233ms/step - loss: 0.2794 - accuracy: 0.9082 - val_loss: 0.6236 - val_accuracy: 0.6800
# Epoch 97/100
# 4/4 [==============================] - 1s 235ms/step - loss: 0.3309 - accuracy: 0.8265 - val_loss: 0.5865 - val_accuracy: 0.7200
# Epoch 98/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.2264 - accuracy: 0.9082 - val_loss: 0.7388 - val_accuracy: 0.6400
# Epoch 99/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.3103 - accuracy: 0.8571 - val_loss: 0.7016 - val_accuracy: 0.6400
# Epoch 100/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.2386 - accuracy: 0.9286 - val_loss: 0.5904 - val_accuracy: 0.7600

# %%
summarize_diagnostics(historyVGG16_v2)

# %%
validateResults(modelv2)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fec18f297a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#               precision    recall  f1-score   support
#
#       Benign       0.71      0.92      0.80        26
#    Malignant       0.67      0.29      0.40        14
#
#     accuracy                           0.70        40
#    macro avg       0.69      0.60      0.60        40
# weighted avg       0.69      0.70      0.66        40
#
# [[24  2]
#  [10  4]]

# %% [markdown]
# VGG16 v3

# %%
from tensorflow.keras.optimizers import RMSprop
def fitVGG16v3():
  modelv3 = BuildVGG16()
  opt = tf.keras.optimizers.SGD(learning_rate=0.01)  
  modelv3.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])


  # fit model
  historyVGG16_v3 = modelv3.fit(
      train_it, 
      steps_per_epoch=len(train_it),
      validation_data=validation_it, 
      validation_steps=len(validation_it), 
      epochs=EPOCHS, 
      verbose=1)
  
  return historyVGG16_v3, modelv3

# %%
historyVGG16_v3, modelv3 = fitVGG16v3()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s
# 4/4 [==============================] - 2s 408ms/step - loss: 0.5957 - accuracy: 0.6531 - val_loss: 0.6554 - val_accuracy: 0.6800
# Epoch 21/100
# 4/4 [==============================] - 2s 555ms/step - loss: 0.6398 - accuracy: 0.6837 - val_loss: 0.7033 - val_accuracy: 0.6000
# Epoch 22/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.7708 - accuracy: 0.5408 - val_loss: 0.6978 - val_accuracy: 0.6000
# Epoch 23/100
# 4/4 [==============================] - 2s 553ms/step - loss: 0.6708 - accuracy: 0.6735 - val_loss: 0.6826 - val_accuracy: 0.6000
# Epoch 24/100
# 4/4 [==============================] - 2s 409ms/step - loss: 0.6261 - accuracy: 0.6939 - val_loss: 1.0825 - val_accuracy: 0.6000
# Epoch 25/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.7837 - accuracy: 0.6939 - val_loss: 0.6882 - val_accuracy: 0.6000
# Epoch 26/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.6503 - accuracy: 0.6837 - val_loss: 0.8285 - val_accuracy: 0.6000
# Epoch 27/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6039 - accuracy: 0.7245 - val_loss: 0.6846 - val_accuracy: 0.6000
# Epoch 28/100
# 4/4 [==============================] - 2s 409ms/step - loss: 0.5766 - accuracy: 0.7347 - val_loss: 0.6835 - val_accuracy: 0.6000
# Epoch 29/100
# 4/4 [==============================] - 2s 431ms/step - loss: 0.6242 - accuracy: 0.6939 - val_loss: 0.6652 - val_accuracy: 0.6000
# Epoch 30/100
# 4/4 [==============================] - 2s 405ms/step - loss: 0.6197 - accuracy: 0.6837 - val_loss: 0.6516 - val_accuracy: 0.6800
# Epoch 31/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6089 - accuracy: 0.6837 - val_loss: 0.7204 - val_accuracy: 0.6000
# Epoch 32/100
# 4/4 [==============================] - 2s 412ms/step - loss: 0.5594 - accuracy: 0.7347 - val_loss: 0.6761 - val_accuracy: 0.6000
# Epoch 33/100
# 4/4 [==============================] - 2s 561ms/step - loss: 0.6361 - accuracy: 0.6939 - val_loss: 0.6726 - val_accuracy: 0.6000
# Epoch 34/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6119 - accuracy: 0.6939 - val_loss: 0.7579 - val_accuracy: 0.6000
# Epoch 35/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.5819 - accuracy: 0.6939 - val_loss: 0.6680 - val_accuracy: 0.6000
# Epoch 36/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.6132 - accuracy: 0.7143 - val_loss: 0.6495 - val_accuracy: 0.6000
# Epoch 37/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.7083 - accuracy: 0.5918 - val_loss: 0.6628 - val_accuracy: 0.6000
# Epoch 38/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.5624 - accuracy: 0.6939 - val_loss: 0.6583 - val_accuracy: 0.6000
# Epoch 39/100
# 4/4 [==============================] - 2s 434ms/step - loss: 0.5978 - accuracy: 0.6429 - val_loss: 0.6390 - val_accuracy: 0.6000
# Epoch 40/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.6876 - accuracy: 0.5408 - val_loss: 0.6317 - val_accuracy: 0.6000
# Epoch 41/100
# 4/4 [==============================] - 2s 400ms/step - loss: 0.5562 - accuracy: 0.7449 - val_loss: 0.6124 - val_accuracy: 0.7600
# Epoch 42/100
# 4/4 [==============================] - 2s 431ms/step - loss: 0.5432 - accuracy: 0.7143 - val_loss: 0.6737 - val_accuracy: 0.6000
# Epoch 43/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.6044 - accuracy: 0.6939 - val_loss: 0.6659 - val_accuracy: 0.6400
# Epoch 44/100
# 4/4 [==============================] - 2s 559ms/step - loss: 0.5644 - accuracy: 0.7245 - val_loss: 0.6749 - val_accuracy: 0.6000
# Epoch 45/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.6133 - accuracy: 0.7245 - val_loss: 0.7605 - val_accuracy: 0.6000
# Epoch 46/100
# 4/4 [==============================] - 2s 405ms/step - loss: 0.5960 - accuracy: 0.6837 - val_loss: 0.8393 - val_accuracy: 0.6000
# Epoch 47/100
# 4/4 [==============================] - 2s 405ms/step - loss: 0.5852 - accuracy: 0.7041 - val_loss: 0.7449 - val_accuracy: 0.6000
# Epoch 48/100
# 4/4 [==============================] - 2s 428ms/step - loss: 0.6778 - accuracy: 0.7041 - val_loss: 0.6578 - val_accuracy: 0.6400
# Epoch 49/100
# 4/4 [==============================] - 2s 416ms/step - loss: 0.5193 - accuracy: 0.7143 - val_loss: 0.6474 - val_accuracy: 0.6400
# Epoch 50/100
# 4/4 [==============================] - 2s 566ms/step - loss: 0.5227 - accuracy: 0.7449 - val_loss: 0.6073 - val_accuracy: 0.7200
# Epoch 51/100
# 4/4 [==============================] - 2s 564ms/step - loss: 0.6535 - accuracy: 0.7143 - val_loss: 0.6356 - val_accuracy: 0.6400
# Epoch 52/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.5640 - accuracy: 0.7143 - val_loss: 0.7177 - val_accuracy: 0.6000
# Epoch 53/100
# 4/4 [==============================] - 2s 551ms/step - loss: 0.5972 - accuracy: 0.6939 - val_loss: 0.6591 - val_accuracy: 0.6000
# Epoch 54/100
# 4/4 [==============================] - 2s 437ms/step - loss: 0.5300 - accuracy: 0.7041 - val_loss: 0.6380 - val_accuracy: 0.6400
# Epoch 55/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.5429 - accuracy: 0.7041 - val_loss: 0.6786 - val_accuracy: 0.6000
# Epoch 56/100
# 4/4 [==============================] - 2s 438ms/step - loss: 0.6002 - accuracy: 0.7041 - val_loss: 0.6423 - val_accuracy: 0.6400
# Epoch 57/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.5085 - accuracy: 0.7653 - val_loss: 0.6895 - val_accuracy: 0.6000
# Epoch 58/100
# 4/4 [==============================] - 2s 411ms/step - loss: 0.5426 - accuracy: 0.7245 - val_loss: 0.7913 - val_accuracy: 0.6000
# Epoch 59/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.5729 - accuracy: 0.7041 - val_loss: 0.5971 - val_accuracy: 0.6800
# Epoch 60/100
# 4/4 [==============================] - 2s 431ms/step - loss: 0.5647 - accuracy: 0.7143 - val_loss: 0.6518 - val_accuracy: 0.6400
# Epoch 61/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.5226 - accuracy: 0.7143 - val_loss: 0.7726 - val_accuracy: 0.6000
# Epoch 62/100
# 4/4 [==============================] - 2s 403ms/step - loss: 0.4909 - accuracy: 0.7449 - val_loss: 0.6247 - val_accuracy: 0.6400
# Epoch 63/100
# 4/4 [==============================] - 2s 427ms/step - loss: 0.5563 - accuracy: 0.6837 - val_loss: 0.6616 - val_accuracy: 0.6000
# Epoch 64/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.5128 - accuracy: 0.7551 - val_loss: 0.6206 - val_accuracy: 0.6800
# Epoch 65/100
# 4/4 [==============================] - 2s 432ms/step - loss: 0.5586 - accuracy: 0.7245 - val_loss: 0.6591 - val_accuracy: 0.6000
# Epoch 66/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.7560 - accuracy: 0.5102 - val_loss: 0.6132 - val_accuracy: 0.6800
# Epoch 67/100
# 4/4 [==============================] - 2s 430ms/step - loss: 0.5618 - accuracy: 0.7245 - val_loss: 0.6330 - val_accuracy: 0.6000
# Epoch 68/100
# 4/4 [==============================] - 2s 429ms/step - loss: 0.5790 - accuracy: 0.7143 - val_loss: 0.6544 - val_accuracy: 0.6000
# Epoch 69/100
# 4/4 [==============================] - 2s 407ms/step - loss: 0.5035 - accuracy: 0.7449 - val_loss: 0.6057 - val_accuracy: 0.6400
# Epoch 70/100
# 4/4 [==============================] - 2s 411ms/step - loss: 0.4902 - accuracy: 0.7857 - val_loss: 0.6338 - val_accuracy: 0.7200
# Epoch 71/100
# 4/4 [==============================] - 2s 432ms/step - loss: 0.5150 - accuracy: 0.7959 - val_loss: 0.6845 - val_accuracy: 0.6000
# Epoch 72/100
# 4/4 [==============================] - 2s 423ms/step - loss: 0.5454 - accuracy: 0.7143 - val_loss: 0.6201 - val_accuracy: 0.6800
# Epoch 73/100
# 4/4 [==============================] - 2s 435ms/step - loss: 0.6290 - accuracy: 0.6633 - val_loss: 0.6184 - val_accuracy: 0.6800
# Epoch 74/100
# 4/4 [==============================] - 2s 431ms/step - loss: 0.5633 - accuracy: 0.7143 - val_loss: 0.6704 - val_accuracy: 0.6000
# Epoch 75/100
# 4/4 [==============================] - 2s 409ms/step - loss: 0.4982 - accuracy: 0.8061 - val_loss: 0.6796 - val_accuracy: 0.6000
# Epoch 76/100
# 4/4 [==============================] - 2s 405ms/step - loss: 0.5593 - accuracy: 0.7245 - val_loss: 0.6236 - val_accuracy: 0.6400
# Epoch 77/100
# 4/4 [==============================] - 2s 561ms/step - loss: 0.5440 - accuracy: 0.7245 - val_loss: 0.7003 - val_accuracy: 0.6000
# Epoch 78/100
# 4/4 [==============================] - 2s 435ms/step - loss: 0.5804 - accuracy: 0.7041 - val_loss: 0.6244 - val_accuracy: 0.6400
# Epoch 79/100
# 4/4 [==============================] - 2s 439ms/step - loss: 0.5354 - accuracy: 0.7347 - val_loss: 0.6831 - val_accuracy: 0.6000
# Epoch 80/100
# 4/4 [==============================] - 2s 434ms/step - loss: 0.5768 - accuracy: 0.7245 - val_loss: 0.6619 - val_accuracy: 0.6000
# Epoch 81/100
# 4/4 [==============================] - 2s 409ms/step - loss: 0.5096 - accuracy: 0.7347 - val_loss: 0.6099 - val_accuracy: 0.6400
# Epoch 82/100
# 4/4 [==============================] - 2s 434ms/step - loss: 0.8272 - accuracy: 0.5816 - val_loss: 0.5957 - val_accuracy: 0.6800
# Epoch 83/100
# 4/4 [==============================] - 2s 450ms/step - loss: 0.4710 - accuracy: 0.8163 - val_loss: 0.6375 - val_accuracy: 0.6800
# Epoch 84/100
# 4/4 [==============================] - 2s 407ms/step - loss: 0.5043 - accuracy: 0.7449 - val_loss: 0.7154 - val_accuracy: 0.6000
# Epoch 85/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.5408 - accuracy: 0.7245 - val_loss: 0.7954 - val_accuracy: 0.6000
# Epoch 86/100
# 4/4 [==============================] - 2s 402ms/step - loss: 0.5424 - accuracy: 0.7245 - val_loss: 0.5861 - val_accuracy: 0.8000
# Epoch 87/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.5510 - accuracy: 0.6939 - val_loss: 0.6343 - val_accuracy: 0.6400
# Epoch 88/100
# 4/4 [==============================] - 2s 430ms/step - loss: 0.5116 - accuracy: 0.7653 - val_loss: 0.6007 - val_accuracy: 0.6800
# Epoch 89/100
# 4/4 [==============================] - 2s 430ms/step - loss: 0.4948 - accuracy: 0.7245 - val_loss: 0.6480 - val_accuracy: 0.6000
# Epoch 90/100
# 4/4 [==============================] - 2s 415ms/step - loss: 0.4518 - accuracy: 0.7551 - val_loss: 0.6620 - val_accuracy: 0.6000
# Epoch 91/100
# 4/4 [==============================] - 2s 437ms/step - loss: 0.5939 - accuracy: 0.7245 - val_loss: 0.6355 - val_accuracy: 0.6000
# Epoch 92/100
# 4/4 [==============================] - 2s 403ms/step - loss: 0.4956 - accuracy: 0.7551 - val_loss: 0.7810 - val_accuracy: 0.6000
# Epoch 93/100
# 4/4 [==============================] - 2s 402ms/step - loss: 0.5400 - accuracy: 0.6939 - val_loss: 0.9134 - val_accuracy: 0.6000
# Epoch 94/100
# 4/4 [==============================] - 2s 555ms/step - loss: 0.4917 - accuracy: 0.7449 - val_loss: 0.6147 - val_accuracy: 0.6800
# Epoch 95/100
# 4/4 [==============================] - 2s 435ms/step - loss: 0.5566 - accuracy: 0.7653 - val_loss: 0.5827 - val_accuracy: 0.7200
# Epoch 96/100
# 4/4 [==============================] - 2s 436ms/step - loss: 0.5382 - accuracy: 0.7653 - val_loss: 0.6859 - val_accuracy: 0.6000
# Epoch 97/100
# 4/4 [==============================] - 2s 405ms/step - loss: 0.5448 - accuracy: 0.6939 - val_loss: 0.8565 - val_accuracy: 0.6000
# Epoch 98/100
# 4/4 [==============================] - 2s 435ms/step - loss: 0.5404 - accuracy: 0.7143 - val_loss: 0.6124 - val_accuracy: 0.6400
# Epoch 99/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.5063 - accuracy: 0.7449 - val_loss: 0.6028 - val_accuracy: 0.7600
# Epoch 100/100
# 4/4 [==============================] - 2s 607ms/step - loss: 0.5405 - accuracy: 0.7245 - val_loss: 0.6482 - val_accuracy: 0.6400

# %%
summarize_diagnostics(historyVGG16_v3)

# %%
validateResults(modelv3)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.79      0.73      0.76        26
#    Malignant       0.56      0.64      0.60        14
#
#     accuracy                           0.70        40
#    macro avg       0.68      0.69      0.68        40
# weighted avg       0.71      0.70      0.70        40
#
# [[19  7]
#  [ 5  9]]
